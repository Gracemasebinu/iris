# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## LOAD DATA

# %%
iris =pd.read_csv(r"C:\Users\OMOTAYO GRACE\Desktop\Excel\iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.head(15)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.tail(15)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# ...

# %%
print("The numbers of rows is:", iris.shape[0], 'row')
# Out:
# The numbers of rows is: 150 row

# %%
print("The numbers of columns is:", iris.shape[0], 'columns')
# Out:
# The numbers of columns is: 150 columns

# %%
iris.sample()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 67           5.8          2.7           4.1          1.0  versicolor

# %%
iris.sample(33)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 69            5.6          2.5           3.9          1.1  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 95            5.7          3.0           4.2          1.2  versicolor
# 141           6.9          3.1           5.1          2.3   virginica
# 127           6.1          3.0           4.9          1.8   virginica
# 70            5.9          3.2           4.8          1.8  versicolor
# 92            5.8          2.6           4.0          1.2  versicolor
# 55            5.7          2.8           4.5          1.3  versicolor
# 88            5.6          3.0           4.1          1.3  versicolor
# 137           6.4          3.1           5.5          1.8   virginica
# 37            4.9          3.1           1.5          0.1      setosa
# 100           6.3          3.3           6.0          2.5   virginica
# ...

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
plt.hist(iris["sepal_length"])
plt.show()

# %%
sns.boxplot(iris["sepal_length"], orient= "v")
plt.show()

# %%
corr = iris.drop('species', axis=1).corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species', palette='Set1')
plt.title('Sepal_length vs Petal Length by Species')
plt.xlabel('Sepal_length (cm)')
plt.ylabel('Petal_length (cm)')
plt.legend(title='Species')
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(iris['sepal_length'], bins=20, kde=True, color='skyblue')
plt.title('Histogram and KDE of Sepal Length')

plt.subplot(1, 2, 2)
sns.histplot(iris['sepal_length'], bins=20, kde=True, color='purple')
plt.title('Density Plot of Sepal Length')

plt.show()

# %%
average_sepal_length = iris.groupby('species')['sepal_length'].mean()

# %%
plt.figure(figsize=(10, 6))
plt.bar(average_sepal_length.index, average_sepal_length, color='purple')
plt.xlabel('Species')
plt.ylabel('Average Sepal Length')
plt.title('Average Sepal Length for Each Species')
plt.show()

# %%
sns.barplot(x= 'species', y="sepal_length",data=iris)
plt.show()

# %%
sns.barplot(x= 'species', y="sepal_width",data=iris, color= "red")
plt.show()

# %%
sns.barplot(x= 'species', y="petal_length",data=iris, color= "green")
plt.show()

# %%
sns.countplot(iris['species'])
plt.show()

# %%
sns.barplot(x= 'species', y="petal_width",data=iris, color= "purple")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_width",y= "petal_width", color= "purple")
plt.show()

# %%
sns.scatterplot(data=iris, x="sepal_width",y= "petal_width", color= "red")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length",y= "petal_width", color= "green")
plt.show()

# %%
sns.scatterplot(data=iris, x="sepal_length",y= "sepal_length", color= "purple")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length",y= "petal_length", color= "purple")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length",y= "sepal_width", color= "purple")
plt.show()

# %%
sns.scatterplot(data=iris, x="petal_length",y= "sepal_length", color= "purple")
plt.show()

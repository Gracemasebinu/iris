# %% [markdown]
# ## importation of libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load your dataset into py

# %%
mkt = pd.read_excel(r"C:\Users\OMOTAYO GRACE\Desktop\Excel\employee dataset.xlsx")
mkt
# Out:
#                   Name  Gender            Department     Salary Start Date  \
# 0           Oona Donan  Female  Business Development   88360.79 2019-09-02
# 1       Freddy Linford  Female              Training   93128.34 2018-03-05
# 2     Mackenzie Hannis  Female              Training   57002.02 2018-04-02
# 3     Collen Dunbleton    Male           Engineering  118976.16 2020-10-16
# 4     Jessica Callcott  Female             Marketing   66017.18 2019-06-27
# ..                 ...     ...                   ...        ...        ...
# 141     Aldrich Glenny    Male  Business Development   90884.32 2020-07-27
# 142      Kelly Corkitt  Female       Human Resources   85264.38 2018-04-30
# 143  Marmaduke Worssam  Female           Engineering   78378.20 2018-12-31
# 144  Hobie Stockbridge    Male           Engineering   92943.89 2021-11-10
# 145       Bryant Scamp  Female       Human Resources   29808.07 2018-07-10
#
#      FTE Employee Status        City      Country
# ...

# %% [markdown]
# ### Data type

# %%
mkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             146 non-null    object
#  1   Gender           146 non-null    object
#  2   Department       146 non-null    object
#  3   Salary           146 non-null    float64
#  4   Start Date       146 non-null    datetime64[ns]
#  5   FTE              146 non-null    float64
#  6   Employee Status  146 non-null    object
#  7   City             146 non-null    object
#  8   Country          146 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 10.4+ KB

# %% [markdown]
# ### The first five rows of the dataset

# %%
mkt.head()
# Out:
#                Name  Gender            Department     Salary Start Date  FTE  \
# 0        Oona Donan  Female  Business Development   88360.79 2019-09-02  1.0
# 1    Freddy Linford  Female              Training   93128.34 2018-03-05  1.0
# 2  Mackenzie Hannis  Female              Training   57002.02 2018-04-02  0.7
# 3  Collen Dunbleton    Male           Engineering  118976.16 2020-10-16  1.0
# 4  Jessica Callcott  Female             Marketing   66017.18 2019-06-27  0.9
#
#   Employee Status        City      Country
# 0       Permanent     Seattle          USA
# 1       Permanent     Seattle          USA
# 2       Temporary   Hyderabad        India
# 3       Permanent  Wellington  New Zealand
# 4       Temporary      Remote       Remote

# %% [markdown]
# ### The last five rows of the dataset

# %%
mkt.tail()
# Out:
#                   Name  Gender            Department    Salary Start Date  \
# 141     Aldrich Glenny    Male  Business Development  90884.32 2020-07-27
# 142      Kelly Corkitt  Female       Human Resources  85264.38 2018-04-30
# 143  Marmaduke Worssam  Female           Engineering  78378.20 2018-12-31
# 144  Hobie Stockbridge    Male           Engineering  92943.89 2021-11-10
# 145       Bryant Scamp  Female       Human Resources  29808.07 2018-07-10
#
#      FTE Employee Status       City Country
# 141  0.5       Temporary   Columbus     USA
# 142  1.0       Permanent    Chennai   India
# 143  0.4       Temporary     Remote  Remote
# 144  1.0       Permanent  Hyderabad   India
# 145  0.3       Temporary  Hyderabad   India

# %%
mkt.tail(10)
# Out:
#                     Name  Gender            Department    Salary Start Date  \
# 136        Hali Behnecke    Male       Human Resources  65569.36 2018-07-12
# 137  Konstantin Timblett  Female              Training  56253.81 2021-08-13
# 138        Grier Kidsley  Female    Product Management  51798.25 2019-07-19
# 139      Mendel  Gentsch    Male       Human Resources  28329.77 2018-10-29
# 140         Rey Chartman  Female              Training  93964.30 2021-09-15
# 141       Aldrich Glenny    Male  Business Development  90884.32 2020-07-27
# 142        Kelly Corkitt  Female       Human Resources  85264.38 2018-04-30
# 143    Marmaduke Worssam  Female           Engineering  78378.20 2018-12-31
# 144    Hobie Stockbridge    Male           Engineering  92943.89 2021-11-10
# 145         Bryant Scamp  Female       Human Resources  29808.07 2018-07-10
#
#      FTE Employee Status       City      Country
# 136  1.0       Permanent   Auckland  New Zealand
# ...

# %% [markdown]
# ## Quick ststistics

# %%
mkt.describe()
# Out:
#               Salary                     Start Date         FTE
# count     146.000000                            146  146.000000
# mean    73410.778493  2019-10-02 06:34:31.232876800    0.874658
# min         0.000000            2018-01-29 00:00:00    0.200000
# 25%     53271.920000            2018-11-26 00:00:00    1.000000
# 50%     73118.645000            2019-08-29 12:00:00    1.000000
# 75%     91858.527500            2020-07-27 00:00:00    1.000000
# max    119022.490000            2021-11-10 00:00:00    1.000000
# std     24585.903789                            NaN    0.243200

# %% [markdown]
# ## Nummber of rows and columns in the dataset

# %%
mkt.shape
# Out:
# (146, 9)

# %%
mkt.shape[0]
# Out:
# 146

# %%
mkt.shape[1]
# Out:
# 9

# %% [markdown]
# ## Numbers of rows in the dataset

# %%
print("The numbers of rows is:", mkt.shape[0], 'row')
# Out:
# The numbers of rows is: 150 row

# %% [markdown]
# ### Number of colums in the dataset

# %%
print("The numbers of columns is:", mkt.shape[0], 'columns')
# Out:
# The numbers of columns is: 146 columns

# %%
mkt.sample()
# Out:
#                Name Gender   Department     Salary Start Date  FTE  \
# 3  Collen Dunbleton   Male  Engineering  118976.16 2020-10-16  1.0
#
#   Employee Status        City      Country
# 3       Permanent  Wellington  New Zealand

# %% [markdown]
# #### Checking for null value

# %%
mkt.isnull()
# Out:
#       Name  Gender  Department  Salary  Start Date    FTE  Employee Status  \
# 0    False   False       False   False       False  False            False
# 1    False   False       False   False       False  False            False
# 2    False   False       False   False       False  False            False
# 3    False   False       False   False       False  False            False
# 4    False   False       False   False       False  False            False
# ..     ...     ...         ...     ...         ...    ...              ...
# 141  False   False       False   False       False  False            False
# 142  False   False       False   False       False  False            False
# 143  False   False       False   False       False  False            False
# 144  False   False       False   False       False  False            False
# 145  False   False       False   False       False  False            False
#
#       City  Country
# 0    False    False
# 1    False    False
# ...
